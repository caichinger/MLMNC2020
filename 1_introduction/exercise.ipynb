# %% [markdown]
# # Exercise: Follow up on the advertising data set
#
# In the first session, we explored the advertising data set and implemented a model to
# better understand how advertising budget influences sales.
#
# The goal of this exercise is to follow up on some of the issues we discussed.
#
# ---
#
# Note: if you have not yet completed the exercise notebook in the `0_pre_class` folder, we recommend to do that.

# %% [markdown]
# Answer below questions.
# The code snippeds already contained in the notebook will provide you with hints.
#
# - **For each question, give the answer by adding it to this cell.**
# - **Before you upload the notebook to learn@WU, make sure it runs through
# without errors. The easiest way to verify that is by doing `Runtime/Restart and run all...`**
#
#
# ## Questions
# 1. Why did we decide to scale the inputs?
# 1. We observed a positive coefficient for TV but a negative for TV^2.
#    What does this mean?
# 1. Using one of the models, describe and interpret the result of spending
#    - no money
#    - and an ever increasing amount of money
#    on sales. Is this behavior reasonable?
# 1. What does computing
#    [`df.corr()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html)
#    tell you about our data, interpret the
#    [correlation coefficients](https://en.wikipedia.org/wiki/Pearson_correlation_coefficient).
# 1. What does
#    [`pd.plotting.scatter_matrix()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.plotting.scatter_matrix.html)
#    tell us about the data?
#
#
#
# ## Answers
# 1. TBA
# 1. TBA
# 1. TBA
# 1. TBA
# 1. TBA

# %%
# to use pandas, we first need to import it
import pandas as pd

# %matplotlib inline
# we can read in the data (a csv file) using the corresponding function as follows
df = pd.read_csv('http://faculty.marshall.usc.edu/gareth-james/ISL/Advertising.csv', index_col=0)
df
# Out:
#         TV  radio  newspaper  sales
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %%
pd.plotting.scatter_matrix(df)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa122df1150>,
# ...
#       dtype=object)
